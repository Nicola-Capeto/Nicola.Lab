# %%
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

c_id = "d90f456ee66b49888a10ec2d594aaa0f"
c_se ="da8545eb569b4d76b9b0ae8874e4706a"

sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id=c_id, client_secret=c_se))

# %%
# The "sp" variable has two useful funtions:
# The first usefull function is:
# .search(q='',limit=n)
# .search(q="track:"+song_name+" artist:"+artist_name,limit=5) to restrict to a song name and artist.
# Where the "q" keyword is the query you want to perform on spotify: song_name, artist,...
# while The "limit" keyword will limit the number of returned results.
#
# The second usefull function is:
# .audio_features([URL|URI|ID])
# which returns some 'features of the song', that after cleanup, we can use in order to characterize a song.

# %%
results = sp.search(q="Lose yourself",limit=3,market="GB")
results
#json_results = json.dumps(results, ensure_ascii=True)
#json_results
#results['tracks']['items'][0]['external_urls']["spotify"]
# Out:
# {'tracks': {'href': 'https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=0&limit=3',
#   'items': [{'album': {'album_type': 'single',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#        'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#        'id': '7dGJo4pcD2V6oG8kP0tJRR',
#        'name': 'Eminem',
#        'type': 'artist',
#        'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/1rfORa9iYmocEsnnZGMVC4'},
#      'href': 'https://api.spotify.com/v1/albums/1rfORa9iYmocEsnnZGMVC4',
#      'id': '1rfORa9iYmocEsnnZGMVC4',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b273b6ef2ebd34efb08cb76f6eec',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e02b6ef2ebd34efb08cb76f6eec',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d00004851b6ef2ebd34efb08cb76f6eec',
#        'width': 64}],
#      'name': 'Just Lose It',
#      'release_date': '2004-01-01',
#      'release_date_precision': 'day',
#      'total_tracks': 2,
#      'type': 'album',
#      'uri': 'spotify:album:1rfORa9iYmocEsnnZGMVC4'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 1,
#     'duration_ms': 322226,
#     'explicit': True,
#     'external_ids': {'isrc': 'USIR10211559'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'},
#     'href': 'https://api.spotify.com/v1/tracks/1v7L65Lzy0j0vdpRjJewt1',
#     'id': '1v7L65Lzy0j0vdpRjJewt1',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lose Yourself - From "8 Mile" Soundtrack',
#     'popularity': 79,
#     'preview_url': 'https://p.scdn.co/mp3-preview/e00024016d3d3687c5f3683edf865c7c962d209a?cid=d90f456ee66b49888a10ec2d594aaa0f',
#     'track_number': 2,
#     'type': 'track',
#     'uri': 'spotify:track:1v7L65Lzy0j0vdpRjJewt1'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/3CjuTytLZz3G9znXt2rJgU'},
#      'href': 'https://api.spotify.com/v1/albums/3CjuTytLZz3G9znXt2rJgU',
#      'id': '3CjuTytLZz3G9znXt2rJgU',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2733f66b5b49ccea004a5ef0db2',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e023f66b5b49ccea004a5ef0db2',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048513f66b5b49ccea004a5ef0db2',
#        'width': 64}],
#      'name': 'SHADYXV',
#      'release_date': '2014-11-24',
#      'release_date_precision': 'day',
#      'total_tracks': 28,
#      'type': 'album',
#      'uri': 'spotify:album:3CjuTytLZz3G9znXt2rJgU'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 2,
#     'duration_ms': 320626,
#     'explicit': True,
#     'external_ids': {'isrc': 'USIR10211559'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/7MJQ9Nfxzh8LPZ9e9u68Fq'},
#     'href': 'https://api.spotify.com/v1/tracks/7MJQ9Nfxzh8LPZ9e9u68Fq',
#     'id': '7MJQ9Nfxzh8LPZ9e9u68Fq',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lose Yourself',
#     'popularity': 74,
#     'preview_url': 'https://p.scdn.co/mp3-preview/150496718f9728eb329bb3a348028d56fcbea85c?cid=d90f456ee66b49888a10ec2d594aaa0f',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:7MJQ9Nfxzh8LPZ9e9u68Fq'},
#    {'album': {'album_type': 'compilation',
#      'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0LyfQWJT6nXafLPZqxe9Of'},
#        'href': 'https://api.spotify.com/v1/artists/0LyfQWJT6nXafLPZqxe9Of',
#        'id': '0LyfQWJT6nXafLPZqxe9Of',
#        'name': 'Various Artists',
#        'type': 'artist',
#        'uri': 'spotify:artist:0LyfQWJT6nXafLPZqxe9Of'}],
#      'external_urls': {'spotify': 'https://open.spotify.com/album/6ihJNwZLZJmPmXgo06H4ty'},
#      'href': 'https://api.spotify.com/v1/albums/6ihJNwZLZJmPmXgo06H4ty',
#      'id': '6ihJNwZLZJmPmXgo06H4ty',
#      'images': [{'height': 640,
#        'url': 'https://i.scdn.co/image/ab67616d0000b2731df11a8c8b0b7cf79ea359c1',
#        'width': 640},
#       {'height': 300,
#        'url': 'https://i.scdn.co/image/ab67616d00001e021df11a8c8b0b7cf79ea359c1',
#        'width': 300},
#       {'height': 64,
#        'url': 'https://i.scdn.co/image/ab67616d000048511df11a8c8b0b7cf79ea359c1',
#        'width': 64}],
#      'name': 'SHADYXV',
#      'release_date': '2014-11-24',
#      'release_date_precision': 'day',
#      'total_tracks': 28,
#      'type': 'album',
#      'uri': 'spotify:album:6ihJNwZLZJmPmXgo06H4ty'},
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/7dGJo4pcD2V6oG8kP0tJRR'},
#       'href': 'https://api.spotify.com/v1/artists/7dGJo4pcD2V6oG8kP0tJRR',
#       'id': '7dGJo4pcD2V6oG8kP0tJRR',
#       'name': 'Eminem',
#       'type': 'artist',
#       'uri': 'spotify:artist:7dGJo4pcD2V6oG8kP0tJRR'}],
#     'disc_number': 2,
#     'duration_ms': 320573,
#     'explicit': False,
#     'external_ids': {'isrc': 'USIR10211570'},
#     'external_urls': {'spotify': 'https://open.spotify.com/track/0s6Yxg9h7eW4M13rDq2N7Z'},
#     'href': 'https://api.spotify.com/v1/tracks/0s6Yxg9h7eW4M13rDq2N7Z',
#     'id': '0s6Yxg9h7eW4M13rDq2N7Z',
#     'is_local': False,
#     'is_playable': True,
#     'name': 'Lose Yourself',
#     'popularity': 49,
#     'preview_url': 'https://p.scdn.co/mp3-preview/d138df4ee1fe555c380c030722c480bdf3e79a50?cid=d90f456ee66b49888a10ec2d594aaa0f',
#     'track_number': 3,
#     'type': 'track',
#     'uri': 'spotify:track:0s6Yxg9h7eW4M13rDq2N7Z'}],
#   'limit': 3,
#   'next': 'https://api.spotify.com/v1/search?query=Lose+yourself&type=track&market=GB&offset=3&limit=3',
#   'offset': 0,
#   'previous': None,
#   'total': 5343}}

# %%
results["tracks"]["items"][0]["external_urls"]["spotify"]
# Out:
# 'https://open.spotify.com/track/1v7L65Lzy0j0vdpRjJewt1'

# %%
track_id=track_id=results["tracks"]["items"][0]["id"]
track_id
# Out:
# '1v7L65Lzy0j0vdpRjJewt1'

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="GB")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %%
tracks1=get_playlist_tracks("spotify", "37i9dQZF1DWXRqgorJj26U")

# %%
tracks2=get_playlist_tracks("spotify", "4gszEsFSlMFP2MKGveA6Kq")

# %%
list_of_audio_features_1=[]
for item in range(0,200):  #the range depends of number of songs
    #print (tracks[item]["track"]["id"])
    list_of_audio_features_1.append(sp.audio_features(tracks1[item]["track"]["id"])[0])

# %%
df_1=pd.DataFrame(list_of_audio_features_1)    
df_1=df_1[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# %%
list_of_audio_features_2=[]
for item in range(0,90):  #the range depends of number of songs
    #print (tracks[item]["track"]["id"])
    list_of_audio_features_2.append(sp.audio_features(tracks[item]["track"]["id"])[0])

# %%
df_2=pd.DataFrame(list_of_audio_features_2)    
df_2=df_2[["danceability","energy","loudness","speechiness","acousticness",
    "instrumentalness","liveness","valence","tempo","id","duration_ms"]]

# %%
df_1
# Out:
#      danceability  energy  loudness  speechiness  acousticness  \
# 0           0.252   0.797    -3.877       0.0328       0.00458
# 1           0.634   0.630    -8.277       0.0310       0.44700
# 2           0.310   0.700    -5.678       0.0470       0.01100
# 3           0.515   0.430    -9.935       0.0372       0.00970
# 4           0.412   0.902   -11.600       0.4050       0.04840
# ..            ...     ...       ...          ...           ...
# 195         0.543   0.529    -9.717       0.0301       0.32600
# 196         0.468   0.607   -11.367       0.0336       0.07200
# 197         0.668   0.447   -11.124       0.0312       0.48000
# 198         0.430   0.463   -10.960       0.0442       0.30300
# 199         0.413   0.725    -5.787       0.0324       0.36900
#
#      instrumentalness  liveness  valence    tempo                      id  \
# 0            0.424000    0.3440    0.199   77.972  3q9npStSssk7sZWotiNQLK
# 1            0.039000    0.1700    0.489  118.628  6H3kDe7CGoWYBabAeVWGiD
# 2            0.009650    0.0828    0.763  188.386  08mG3Y1vljYA6bvDt4Wqkj
# 3            0.000133    0.1290    0.104   91.844  70LcF31zb1H0PyJoS1Sx1r
# 4            0.131000    0.4050    0.422   89.740  0hCB0YR03f6AmQaHbwWDe8
# ..                ...       ...      ...      ...                     ...
# 195          0.002690    0.7090    0.746   85.126  3KPwt1LBpt1jVSHz8GXERo
# 196          0.000852    0.2250    0.886   98.429  3MODES4TNtygekLl146Dxd
# 197          0.000003    0.1530    0.588   81.415  5AoZknxgY6F25gAcVahO41
# 198          0.000058    0.1520    0.660   93.405  1IqFh00G2kvvMm8pRMpehA
# 199          0.000022    0.0905    0.440  124.618  5uvosCdMlFdTXhoazkTI5R
#
#      duration_ms
# 0         535733
# 1         270773
# 2         255493
# 3         238640
# 4         333893
# ..           ...
# 195       313840
# 196       263333
# 197       281000
# 198       271333
# 199       429760
#
# [200 rows x 11 columns]

# %%
df_2
# Out:
#     danceability  energy  loudness  speechiness  acousticness  \
# 0          0.683   0.401    -6.335       0.0600        0.5820
# 1          0.842   0.344   -11.514       0.0678        0.4520
# 2          0.329   0.358   -11.556       0.0364        0.2440
# 3          0.835   0.341   -10.580       0.0841        0.4800
# 4          0.741   0.646    -7.741       0.0910        0.1980
# ..           ...     ...       ...          ...           ...
# 85         0.825   0.228    -9.346       0.2670        0.1510
# 86         0.821   0.455    -8.418       0.0551        0.0285
# 87         0.798   0.428    -9.143       0.0411        0.6800
# 88         0.669   0.420    -8.742       0.1230        0.2360
# 89         0.776   0.348    -9.432       0.0730        0.1930
#
#     instrumentalness  liveness  valence    tempo                      id  \
# 0           0.002970    0.1040    0.780  173.008  682zEbP3lcoIZQAuHqrjdw
# 1           0.000871    0.1390    0.892   80.256  3fV7EEa3WYua3UKR9QMqE4
# 2           0.001320    0.1170    0.929  203.555  4m5fhCOKDafJ0I2aeX3728
# 3           0.000121    0.1660    0.626   74.620  5HN2aLIPUbHhZY3dWwI3hE
# 4           0.363000    0.0678    0.894   81.272  1Q95KrgmN7tDvcgF8lqjHu
# ..               ...       ...      ...      ...                     ...
# 85          0.002370    0.0977    0.764   86.169  1OrefE7WUesBWKNnEGVyny
# 86          0.014600    0.0832    0.860   81.868  1pzos30hiaLNUWriGn3igg
# 87          0.000003    0.0880    0.913   91.197  32RtfatCoPyVj659kLFUhi
# 88          0.000006    0.0845    0.789  175.559  2uhRLdoJnLaXTZatZ8QPhk
# 89          0.000091    0.0622    0.733   79.052  3FvRbl5ubDCbGtOjt2S5tD
#
#     duration_ms
# 0        158427
# 1        169347
# 2        153467
# 3        143560
# 4        158133
# ..          ...
# 85       157253
# 86       177672
# 87       189627
# 88       132827
# 89       168000
#
# [90 rows x 11 columns]

# %%
from IPython.display import IFrame

#track_id = "1rfORa9iYmocEsnnZGMVC4"
track_id= 'spotify:track:3hgl7EQwTutSm6PESsB7gZ'
IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/spotify:track:3hgl7EQwTutSm6PESsB7gZ?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
play_song("1Q95KrgmN7tDvcgF8lqjHu")
# Out:
#         <iframe
#             width="320"
#             height="80"
#             src="https://open.spotify.com/embed/track/1Q95KrgmN7tDvcgF8lqjHu?frameborder=0&allowtransparency=true&allow=encrypted-media"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
